# %%
import torch
from torch import nn
from torchvision import datasets, transforms
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import math
import time

# %% [markdown]
# ## Normalize data with testing data
# ##### use default normalizing condition which is mean, std of mnist training dataset which we use as testing data

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,),(0.3081,)),  # mean value = 0.1307, standard deviation value = 0.3081
])

# %% [markdown]
# ## Use Mnist train as test and vice versa

# %%
data_path = './MNIST'

data_test   = datasets.MNIST(root = data_path, train= True, download=True, transform= transform)
data_train  = datasets.MNIST(root = data_path, train= False, download=True, transform= transform)

# %%
print("the number of your training data (must be 10,000) = ", data_train.__len__())
print("hte number of your testing data (must be 60,000) = ", data_test.__len__())
# Out:
# the number of your training data (must be 10,000) =  10000
# hte number of your testing data (must be 60,000) =  60000

# %% [markdown]
# ## Optimization
# #### use any stochastic gradient descent algorithm for the optimization
# #### use any size of the mini-batch
# #### use any optimization algorithm (for example, Momentum, AdaGrad, RMSProp, Adam)
# #### use any regularization algorithm (for example, Dropout, Weight Decay)
# #### use any annealing scheme for the learning rate (for example, constant, decay, staircase)

# %% [markdown]
# ## Desigining Model
# #### design a neural network architecture with a combination of convolutional layers and fully connected layers
# #### use any number of feature layers (convolutional layers)
# #### use any size of convolutional kernel_size
# #### use any number of classification layers (fully connected layers)
# #### use any dimension of classification layers
# #### use any type of activation functions
# #### one example model of the convolutional neural network is as follows:

# %%
import torch.nn as nn
import torch.nn.functional as F
import math

class MyModel(nn.Module):

    def __init__(self, num_classes=10, size_kernel=5):

        super(MyModel, self).__init__()

        # *********************************************************************
        # input parameter
        #
        # data size:
        #   mnist   : 28 * 28
        # *********************************************************************
        self.number_class   = num_classes
        self.size_kernel    = size_kernel        
        
        # *********************************************************************
        # feature layer
        # *********************************************************************
        self.conv1          = nn.Conv2d(1, 20, kernel_size=size_kernel, stride=1, padding=int((size_kernel-1)/2), bias=True)
        self.conv2          = nn.Conv2d(20, 50, kernel_size=size_kernel, stride=1, padding=int((size_kernel-1)/2), bias=True)

        self.conv_layer1    = nn.Sequential(self.conv1, nn.MaxPool2d(kernel_size=2), nn.ReLU(True))
        self.conv_layer2    = nn.Sequential(self.conv2, nn.MaxPool2d(kernel_size=2), nn.ReLU(True))

        self.feature        = nn.Sequential(self.conv_layer1, self.conv_layer2)
        
        # *********************************************************************
        # classifier layer
        # *********************************************************************
        self.fc1        = nn.Linear(50*7*7, 50, bias=True)
        self.fc2        = nn.Linear(50, num_classes, bias=True)

        self.fc_layer1  = nn.Sequential(self.fc1, nn.ReLU(True))
        self.fc_layer2  = nn.Sequential(self.fc2, nn.ReLU(True))

        self.classifier = nn.Sequential(self.fc_layer1, self.fc_layer2)
        
        self._initialize_weight()        
        
    def _initialize_weight(self):

        for m in self.modules():
            
            if isinstance(m, nn.Conv2d):
                
                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))

                if m.bias is not None:

                    m.bias.data.zero_()

            elif isinstance(m, nn.Linear):

                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))
                
                if m.bias is not None:

                    m.bias.data.zero_()

    def forward(self, x):

        x = self.feature(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)

        return x

# %%
classifier1 = MyModel().to("cuda")

# %%
data_train.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-cb246c4c9199> in <module>
# ----> 1 data_train.shape
#
# AttributeError: 'MNIST' object has no attribute 'shape'

# %% [markdown]
# # Define a learning function

# %%
from torch.optim.lr_scheduler import StepLR

def startTraining(batch_size,epoch,learning_rate_value, optimizer_string, learning_rate_decay, classifier):
    #start training 
    start_time = time.time()
    print("start training for", optimizer_string)
    device = "cuda"
    
    optimizer = torch.optim.SGD(classifier.parameters(), lr=learning_rate_value)
    if optimizer_string == "Adam":
        optimizer = torch.optim.Adam(classifier.parameters(), lr=learning_rate_value)
    if optimizer_string == "RMSprop":
        optimizer = torch.optim.RMSprop(classifier.parameters(), lr=learning_rate_value)
    if optimizer_string == "Adagrad":
        optimizer = torch.optim.Adagrad(classifier.parameters(), lr=learning_rate_value)
    criterion = nn.CrossEntropyLoss();
    #define array to save values
    
    scheduler = StepLR(optimizer, step_size=10, gamma = learning_rate_decay)
    
    
    loss_train_arr=np.zeros(epoch)
    accuracy_train_arr=np.zeros(epoch)
    loss_test_arr=np.zeros(epoch)
    accuracy_test_arr=np.zeros(epoch)

    batched_train = torch.utils.data.DataLoader(data_train, batch_size, shuffle=True)
    test = torch.utils.data.DataLoader(data_test)
    
    best_accuracy = 0.95
    best_epoch = 0;
    
    for i in range(epoch):
        loss_train=0
        accuracy_train=0
        loss_test=0
        accuracy_test=0
        
        classifier.train()
        #train and compute loss, accuracy
        for img, label in batched_train:
            img=img.to(device)
            label=label.to(device)
            optimizer.zero_grad()
            predicted = classifier(img)

            label_predicted = torch.argmax(predicted,dim=1)
            loss = criterion(predicted, label)
            loss.backward()
            optimizer.step()
            

            loss_train += loss.item()
            accuracy_train += torch.sum(label_predicted==label)
        
        #learning rate decay
        scheduler.step()

        loss_train_arr[i]=loss_train/(len(batched_train)) 
        accuracy_train_arr[i]=accuracy_train/len(batched_train.dataset)
        
        classifier.eval()
        #test, no need to backward, step
        
        for img, label in test:
            img=img.to(device)
            label=label.to(device)
            
            with torch.autograd.no_grad():
                predicted = classifier(img)
                label_predicted = torch.argmax(predicted,dim=1)
                loss = criterion(predicted, label)

                loss_test += loss.item()
                accuracy_test += torch.sum(label_predicted==label)

        loss_test_arr[i]=loss_test/(len(test))
        accuracy_test_arr[i]=accuracy_test/len(test.dataset)
        
        if accuracy_test_arr[i] > best_accuracy:
            best_accuracy = accuracy_test_arr[i]
            best_epoch = i
            print("epoch ", i, "reached best accuracy ", best_accuracy, '%');
        

        if i%10==0:
            print("epoch ",i)
            print("train loss", loss_train_arr[i],"train accuracy: ",accuracy_train_arr[i])
            print("test loss", loss_test_arr[i],"test accuracy", accuracy_test_arr[i])
            
    print("execution time =======", time.time()-start_time)
    
    
    return loss_train_arr, loss_test_arr, accuracy_train_arr, accuracy_test_arr, best_epoch

# %% [markdown]
# ## Loss function - cross entropy

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## Start Training for first model

# %%
batch_size = 32
epoch = 100
learning_rate_value = 0.1
weight_decay = 0.7

# %%
class Conv_Fully_Net(nn.Module):
    def __init__(self):
        super(Conv_Fully_Net, self).__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 10, kernel_size=5),
            nn.MaxPool2d(2),
            nn.ReLU(),
            nn.Conv2d(10, 20, kernel_size=5),
            nn.Dropout(),
            nn.MaxPool2d(2),
            nn.ReLU(),
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(320, 50),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(50, 10),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(-1, 320)
        x = self.fc_layers(x)
        return x

# %%
classifier2 = Conv_Fully_Net().to("cuda")

# %%
loss_train_2, loss_test_2, acc_train_2, acc_test_2, best_2 = startTraining(batch_size,epoch,learning_rate_value, "SGD", weight_decay, classifier2)
# Out:
# start training for SGD
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([32, 20, 4, 4])
# torch.Size([16, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# ...
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# torch.Size([1, 20, 4, 4])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-385085050b48> in <module>
# ----> 1 loss_train_2, loss_test_2, acc_train_2, acc_test_2, best_2 = startTraining(batch_size,epoch,learning_rate_value, "SGD", weight_decay, classifier2)
#
# <ipython-input-74-6c47a5bdd793> in startTraining(batch_size, epoch, learning_rate_value, optimizer_string, learning_rate_decay, classifier)
#      64
#      65         for img, label in test:
# ---> 66             img=img.to(device)
#      67             label=label.to(device)
#      68
#
# KeyboardInterrupt:

# %%
loss_train_2, loss_test_2, acc_train_2, acc_test_2, best_2 = startTraining(batch_size,epoch,learning_rate_value, "SGD", weight_decay, classifier2)
# Out:
# start training for SGD
# epoch  0
# train loss 1.9767461611440007 train accuracy:  0.4959999918937683
# test loss 1.6959648148675759 test accuracy 0.786050021648407
# epoch  2 reached best accuracy  0.9185000061988831 %
# epoch  4 reached best accuracy  0.9412000179290771 %
# epoch  5 reached best accuracy  0.9427333474159241 %
# epoch  7 reached best accuracy  0.9441500306129456 %
# epoch  8 reached best accuracy  0.9503166675567627 %
# epoch  10 reached best accuracy  0.9509833455085754 %
# epoch  10
# train loss 1.5394700099104128 train accuracy:  0.9220999479293823
# test loss 1.5106864646931488 test accuracy 0.9509833455085754
# epoch  11 reached best accuracy  0.9549500346183777 %
# epoch  12 reached best accuracy  0.9608166813850403 %
# epoch  13 reached best accuracy  0.9611666798591614 %
# epoch  14 reached best accuracy  0.9637166857719421 %
# epoch  16 reached best accuracy  0.9640166759490967 %
# epoch  17 reached best accuracy  0.9653833508491516 %
# epoch  18 reached best accuracy  0.9659667015075684 %
# epoch  19 reached best accuracy  0.9679333567619324 %
# epoch  20
# train loss 1.5109292436331605 train accuracy:  0.950499951839447
# test loss 1.4940363447805245 test accuracy 0.9672166705131531
# epoch  23 reached best accuracy  0.9701499938964844 %
# epoch  27 reached best accuracy  0.9711666703224182 %
# epoch  29 reached best accuracy  0.9721666574478149 %
# epoch  30
# train loss 1.5020430274664784 train accuracy:  0.9598000049591064
# test loss 1.4902446476320426 test accuracy 0.9711499810218811
# epoch  32 reached best accuracy  0.9732000231742859 %
# epoch  33 reached best accuracy  0.9737666845321655 %
# epoch  36 reached best accuracy  0.9747333526611328 %
# epoch  40 reached best accuracy  0.9754000306129456 %
# epoch  40
# train loss 1.4936350283150475 train accuracy:  0.968999981880188
# test loss 1.4859432437916598 test accuracy 0.9754000306129456
# epoch  44 reached best accuracy  0.9754666686058044 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-385085050b48> in <module>
# ----> 1 loss_train_2, loss_test_2, acc_train_2, acc_test_2, best_2 = startTraining(batch_size,epoch,learning_rate_value, "SGD", weight_decay, classifier2)
#
# <ipython-input-63-dcc5d172e559> in startTraining(batch_size, epoch, learning_rate_value, optimizer_string, learning_rate_decay, classifier)
#      64
#      65         for img, label in test:
# ---> 66             img=img.to(device)
#      67             label=label.to(device)
#      68
#
# KeyboardInterrupt:

# %%
plt.figure(1,figsize=(10,10))

plt.plot(loss_train_2,label="train loss",c="red")
plt.plot(loss_test_2,label="test loss",c="blue")
plt.title("classifier1\n\nloss")
plt.legend()
plt.plot()
# Out:
# []

# %%
plt.figure(1,figsize=(10,10))

plt.plot(acc_train_2,label="train accuracy",c="red")
plt.plot(acc_test_2,label="test accuracy",c="blue")
plt.title("classifier1\n\naccuracy")
plt.legend()
plt.plot()
# Out:
# []

# %%
class Model3(nn.Module):
    def __init__(self):
        super(Model3, self).__init__()
        
        #Output Size = (W - F + 2P) / S + 1
        #input size = 28 * 28
        self.conv_1 = nn.Sequential(
            nn.Conv2d(1, 20, kernel_size=(3,3), padding = 1), # (28 - 3  + 2)/1 + 1 = 28 * 28
            nn.MaxPool2d(2), # 14 * 14
            nn.Dropout(),
            nn.ReLU(),
        )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(20, 20, kernel_size=(3,3), padding = 1), #14 * 14        
            nn.MaxPool2d(kernel_size=(2,2)), # 7 * 7
            nn.Dropout(),
            nn.ReLU(),
        )
        
        self.conv_3 = nn.Sequential(
            nn.Conv2d(20, 10, kernel_size=(3,3)), # (7 - 3) + 1 = 5 * 5
            nn.Dropout(),
            nn.ReLU()
        )
        
        self.fc = nn.Sequential(
            #input = 5 * 5 *10
            nn.Linear(250, 128),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(64, 10),
            nn.Softmax(dim=1)
        )
        
        self._initialize_weight() 

    def forward(self, x):
        x = self.conv_1(x)
        x = self.conv_2(x)
        x = self.conv_3(x)
        x = x.view(-1, 250)
        x = self.fc(x)
        return x
    
    def _initialize_weight(self):

        for m in self.modules():
            
            if isinstance(m, nn.Conv2d):
                
                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))

                if m.bias is not None:

                    m.bias.data.zero_()

            elif isinstance(m, nn.Linear):

                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))
                
                if m.bias is not None:

                    m.bias.data.zero_()

# %% [markdown]
# batch_size = 32
# epoch = 50
# learning_rate_value = 0.5
# weight_decay = 0.5

# %%
batch_size = 32
epoch = 50
learning_rate_value = 0.5
weight_decay = 0.5

# %%
classifier3 = Model3().to("cuda")

# %%
loss_train_3, loss_test_3, acc_train_3, acc_test_3, best_3 = startTraining(batch_size,epoch,learning_rate_value, "SGD", weight_decay, classifier3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3ffaee9d35f7> in <module>
# ----> 1 loss_train_3, loss_test_3, acc_train_3, acc_test_3, best_3 = startTraining(batch_size,epoch,learning_rate_value, "SGD", weight_decay, classifier3)
#
# NameError: name 'classifier3' is not defined

# %% [markdown]
# too many parameters.... learning process does not advance

# %%
class Model5(nn.Module):
    def __init__(self):
        super(Model5, self).__init__()
        
        #Output Size = (W - F + 2P) / S + 1
        #input size = 28 * 28
        self.conv_1 = nn.Sequential(
            nn.Conv2d(1, 32, 5), # (28 - 5)/1 + 1 = 24 * 24
            nn.MaxPool2d(2), # 12 * 12
            nn.Dropout(0.4),
            nn.ReLU(),
        )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(32, 64, 5), #1 (12 - 5 )/1 +1 = 8 * 8        
            nn.MaxPool2d(2), # 4 * 4
            nn.Dropout(0.5),
            nn.ReLU(),
        )
        
        self.fc = nn.Sequential(
            #input = 4*4*64
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(256, 10),
            nn.Softmax(dim=1)
        )
        
        self._initialize_weight() 

    def forward(self, x):
        x = self.conv_1(x)
        x = self.conv_2(x)
        x = x.view(-1, 1024)
        x = self.fc(x)
        return x
    
    def _initialize_weight(self):

        for m in self.modules():
            
            if isinstance(m, nn.Conv2d):
                
                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))

                if m.bias is not None:

                    m.bias.data.zero_()

            elif isinstance(m, nn.Linear):

                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))
                
                if m.bias is not None:

                    m.bias.data.zero_()

# %%
classifier5 = Model5().to("cuda")
batch_size = 32
epoch = 50
learning_rate_value = 0.1
weight_decay = 0.6

# %%
loss_train_5, loss_test_5, acc_train_5, acc_test_5, best_5 = startTraining(batch_size,epoch,learning_rate_value, "Sgd", weight_decay, classifier5)
# Out:
# start training for Sgd
# epoch  0
# train loss 2.0061541136842185 train accuracy:  0.4504999816417694
# test loss 1.7405927754024664 test accuracy 0.7243666648864746
# epoch  9 reached best accuracy  0.9541000127792358 %
# epoch  10 reached best accuracy  0.9664833545684814 %
# epoch  10
# train loss 1.5312334756119945 train accuracy:  0.9298999905586243
# test loss 1.4950306580901145 test accuracy 0.9664833545684814
# epoch  11 reached best accuracy  0.9690833687782288 %
# epoch  13 reached best accuracy  0.9696666598320007 %
# epoch  15 reached best accuracy  0.9719333648681641 %
# epoch  16 reached best accuracy  0.9721333384513855 %
# epoch  17 reached best accuracy  0.9728833436965942 %
# epoch  18 reached best accuracy  0.9733499884605408 %
# epoch  20 reached best accuracy  0.9740833640098572 %
# epoch  20
# train loss 1.5029028391304868 train accuracy:  0.958299994468689
# test loss 1.4872369211455185 test accuracy 0.9740833640098572
# epoch  21 reached best accuracy  0.9754000306129456 %
# epoch  24 reached best accuracy  0.9766166806221008 %
# epoch  27 reached best accuracy  0.9767667055130005 %
# epoch  28 reached best accuracy  0.9769499897956848 %
# epoch  29 reached best accuracy  0.9771000146865845 %
# epoch  30 reached best accuracy  0.9776000380516052 %
# epoch  30
# train loss 1.4952054130383574 train accuracy:  0.9661999940872192
# test loss 1.4835373209555944 test accuracy 0.9776000380516052
# epoch  31 reached best accuracy  0.9776833653450012 %
# epoch  33 reached best accuracy  0.9788833260536194 %
# epoch  37 reached best accuracy  0.9790500402450562 %
# epoch  39 reached best accuracy  0.9792333245277405 %
# epoch  40 reached best accuracy  0.9796333312988281 %
# epoch  40
# train loss 1.4904924356899323 train accuracy:  0.9717999696731567
# test loss 1.4817795595983665 test accuracy 0.9796333312988281
# epoch  43 reached best accuracy  0.9801166653633118 %
# epoch  46 reached best accuracy  0.980316698551178 %
# execution time ======= 4305.807051897049

# %%
acc_test_5[45]
# Out:
# 0.9797833561897278

# %%
plt.figure(1,figsize=(10,10))

plt.plot(loss_train_5,label="train loss",c="red")
plt.plot(loss_test_5,label="test loss",c="blue")
plt.title("classifier1\n\nloss")
plt.legend()
plt.plot()
# Out:
# []

# %%
plt.figure(1,figsize=(10,10))

plt.plot(acc_train_5,label="train accuracy",c="red")
plt.plot(acc_test_5,label="test accuracy",c="blue")
plt.title("classifier1\n\naccuracy")
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# ## seems the reason of the higher test accuracy is dropout.. try with code

# %%
class Model5_noDrop(nn.Module):
    def __init__(self):
        super(Model5_noDrop, self).__init__()
        
        #Output Size = (W - F + 2P) / S + 1
        #input size = 28 * 28
        self.conv_1 = nn.Sequential(
            nn.Conv2d(1, 32, 5), # (28 - 5)/1 + 1 = 24 * 24
            nn.MaxPool2d(2), # 12 * 12
            nn.ReLU(),
        )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(32, 64, 5), #1 (12 - 5 )/1 +1 = 8 * 8        
            nn.MaxPool2d(2), # 4 * 4
            nn.ReLU(),
        )
        
        self.fc = nn.Sequential(
            #input = 4*4*64
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Linear(256, 10),
            nn.Softmax(dim=1)
        )
        
        self._initialize_weight() 

    def forward(self, x):
        x = self.conv_1(x)
        x = self.conv_2(x)
        x = x.view(-1, 1024)
        x = self.fc(x)
        return x
    
    def _initialize_weight(self):

        for m in self.modules():
            
            if isinstance(m, nn.Conv2d):
                
                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))

                if m.bias is not None:

                    m.bias.data.zero_()

            elif isinstance(m, nn.Linear):

                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))
                
                if m.bias is not None:

                    m.bias.data.zero_()

# %%
classifier6 = Model5_noDrop().to("cuda")
batch_size = 32
epoch = 50
learning_rate_value = 0.1
weight_decay = 0.6

# %%
loss_train_6, loss_test_6, acc_train_6, acc_test_6, best_6 = startTraining(batch_size,epoch,learning_rate_value, "Sgd", weight_decay, classifier6)
# Out:
# start training for Sgd
# epoch  0
# train loss 1.7482508257174263 train accuracy:  0.7184000015258789
# test loss 1.6533295202493667 test accuracy 0.8146166801452637
# epoch  4 reached best accuracy  0.9640333652496338 %
# epoch  5 reached best accuracy  0.9731500148773193 %
# epoch  10 reached best accuracy  0.9761666655540466 %
# epoch  10
# train loss 1.4660286118809027 train accuracy:  0.9957000017166138
# test loss 1.4861129914840063 test accuracy 0.9761666655540466
# epoch  12 reached best accuracy  0.9764500260353088 %
# epoch  14 reached best accuracy  0.9779166579246521 %
# epoch  15 reached best accuracy  0.9781166911125183 %
# epoch  17 reached best accuracy  0.9781833291053772 %
# epoch  19 reached best accuracy  0.9783833622932434 %
# epoch  20
# train loss 1.4639096343860079 train accuracy:  0.9972999691963196
# test loss 1.4837050981700421 test accuracy 0.9783833622932434
# epoch  28 reached best accuracy  0.9784166812896729 %
# epoch  29 reached best accuracy  0.9784833192825317 %
# epoch  30
# train loss 1.4636933883539023 train accuracy:  0.9975000023841858
# test loss 1.4835122857173284 test accuracy 0.9784666895866394
# epoch  40
# train loss 1.463497221279449 train accuracy:  0.9976999759674072
# test loss 1.483550326325496 test accuracy 0.9783999919891357
# epoch  44 reached best accuracy  0.9785000085830688 %
# execution time ======= 4051.90665435791

# %%
plt.figure(1,figsize=(10,10))

plt.plot(loss_train_6,label="train loss",c="red")
plt.plot(loss_test_6,label="test loss",c="blue")
plt.title("classifier1\n\nloss")
plt.legend()
plt.plot()
# Out:
# []

# %%
plt.figure(1,figsize=(10,10))

plt.plot(acc_train_6,label="train accuracy",c="red")
plt.plot(acc_test_6,label="test accuracy",c="blue")
plt.title("classifier1\n\naccuracy")
plt.legend()
plt.plot()
# Out:
# []

# %%
class Model7(nn.Module):
    def __init__(self):
        super(Model7, self).__init__()
        
        #Output Size = (W - F + 2P) / S + 1
        #input size = 28 * 28
        self.conv_1 = nn.Sequential(
            nn.Conv2d(1, 50, 5), # (28 - 5)/1 + 1 = 24 * 24
            nn.MaxPool2d(2), # 12 * 12
            nn.Dropout(0.4),
            nn.ReLU(),
        )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(50, 100, 5), #1 (12 - 5 )/1 +1 = 8 * 8        
            nn.MaxPool2d(2), # 4 * 4
            nn.Dropout(0.5),
            nn.ReLU(),
        )
        
        self.fc = nn.Sequential(
            #input = 4*4*100
            nn.Linear(1600, 200),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(200, 10),
            nn.Softmax(dim=1)
        )
        
        self._initialize_weight() 

    def forward(self, x):
        x = self.conv_1(x)
        x = self.conv_2(x)
        x = x.view(-1, 1600)
        x = self.fc(x)
        return x
    
    def _initialize_weight(self):

        for m in self.modules():
            
            if isinstance(m, nn.Conv2d):
                
                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))

                if m.bias is not None:

                    m.bias.data.zero_()

            elif isinstance(m, nn.Linear):

                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))
                
                if m.bias is not None:

                    m.bias.data.zero_()

# %%
classifier7 = Model7().to("cuda")
batch_size = 32
epoch = 80
learning_rate_value = 0.1
weight_decay = 0.8

# %%
loss_train_7, loss_test_7, acc_train_7, acc_test_7, best_7 = startTraining(batch_size,epoch,learning_rate_value, "Sgd", weight_decay, classifier7)
# Out:
# start training for Sgd
# epoch  0
# train loss 1.9263344896487153 train accuracy:  0.5299999713897705
# test loss 1.6527905102193357 test accuracy 0.81208336353302
# epoch  4 reached best accuracy  0.9544833302497864 %
# epoch  5 reached best accuracy  0.9556166529655457 %
# epoch  6 reached best accuracy  0.9599000215530396 %
# epoch  7 reached best accuracy  0.9645000100135803 %
# epoch  9 reached best accuracy  0.9649333357810974 %
# epoch  10 reached best accuracy  0.96833336353302 %
# epoch  10
# train loss 1.5105302589008223 train accuracy:  0.9508999586105347
# test loss 1.4928726790626843 test accuracy 0.96833336353302
# epoch  11 reached best accuracy  0.9701666831970215 %
# epoch  13 reached best accuracy  0.9705833196640015 %
# epoch  14 reached best accuracy  0.9715666770935059 %
# epoch  15 reached best accuracy  0.9732166528701782 %
# epoch  16 reached best accuracy  0.973300039768219 %
# epoch  17 reached best accuracy  0.9743500351905823 %
# epoch  18 reached best accuracy  0.9750166535377502 %
# epoch  19 reached best accuracy  0.9762333631515503 %
# epoch  20 reached best accuracy  0.9764500260353088 %
# epoch  20
# train loss 1.4943797771161356 train accuracy:  0.9668999910354614
# test loss 1.484574817121029 test accuracy 0.9764500260353088
# epoch  21 reached best accuracy  0.9766166806221008 %
# epoch  22 reached best accuracy  0.9770833253860474 %
# epoch  23 reached best accuracy  0.9775333404541016 %
# epoch  24 reached best accuracy  0.978600025177002 %
# epoch  29 reached best accuracy  0.9786999821662903 %
# epoch  30 reached best accuracy  0.9801000356674194 %
# epoch  30
# train loss 1.4858916346638347 train accuracy:  0.9756999611854553
# test loss 1.481191833615303 test accuracy 0.9801000356674194
# epoch  32 reached best accuracy  0.9804333448410034 %
# epoch  33 reached best accuracy  0.9806666970252991 %
# epoch  40 reached best accuracy  0.9811333417892456 %
# epoch  40
# train loss 1.4826460261695302 train accuracy:  0.9785999655723572
# test loss 1.4800901201665402 test accuracy 0.9811333417892456
# epoch  41 reached best accuracy  0.9817000031471252 %
# epoch  43 reached best accuracy  0.9820666909217834 %
# epoch  49 reached best accuracy  0.9822666645050049 %
# epoch  50 reached best accuracy  0.9825167059898376 %
# epoch  50
# train loss 1.4801532190066937 train accuracy:  0.981499969959259
# test loss 1.4785296447853247 test accuracy 0.9825167059898376
# epoch  51 reached best accuracy  0.98253333568573 %
# epoch  54 reached best accuracy  0.9830999970436096 %
# epoch  60
# train loss 1.4786884670440381 train accuracy:  0.9824999570846558
# test loss 1.4785548857033253 test accuracy 0.982699990272522
# epoch  61 reached best accuracy  0.9832167029380798 %
# epoch  64 reached best accuracy  0.9834333658218384 %
# epoch  70
# train loss 1.4773203519205698 train accuracy:  0.9842999577522278
# test loss 1.4782580355346202 test accuracy 0.9830499887466431
# epoch  72 reached best accuracy  0.9837166666984558 %
# epoch  75 reached best accuracy  0.9839000105857849 %
# epoch  77 reached best accuracy  0.9841333627700806 %
# epoch  78 reached best accuracy  0.9842166900634766 %
# execution time ======= 7271.212631702423

# %%
class Model8(nn.Module):
    def __init__(self):
        super(Model8, self).__init__()
        
        #Output Size = (W - F + 2P) / S + 1
        #input size = 28 * 28
        self.conv_1 = nn.Sequential(
            nn.Conv2d(1, 60, 5), # (28 - 5)/1 + 1 = 24 * 24
            nn.MaxPool2d(2), # 12 * 12
            nn.Dropout(0.4),
            nn.ReLU(),
        )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(60, 120, 5), #1 (12 - 5 )/1 +1 = 8 * 8        
            nn.MaxPool2d(2), # 4 * 4
            nn.Dropout(0.5),
            nn.ReLU(),
        )
        
        self.fc = nn.Sequential(
            #input = 4*4*120
            nn.Linear(1920, 300),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(300, 10),
            nn.Softmax(dim=1)
        )
        
        self._initialize_weight() 

    def forward(self, x):
        x = self.conv_1(x)
        x = self.conv_2(x)
        x = x.view(-1, 1920)
        x = self.fc(x)
        return x
    
    def _initialize_weight(self):

        for m in self.modules():
            
            if isinstance(m, nn.Conv2d):
                
                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))

                if m.bias is not None:

                    m.bias.data.zero_()

            elif isinstance(m, nn.Linear):

                nn.init.xavier_uniform_(m.weight, gain=math.sqrt(2))
                
                if m.bias is not None:

                    m.bias.data.zero_()

# %%
classifier8 = Model8().to("cuda")
batch_size = 32
epoch = 100
learning_rate_value = 0.12
weight_decay = 0.9

# %%
loss_train_8, loss_test_8, acc_train_8, acc_test_8, best_8 = startTraining(batch_size,epoch,learning_rate_value, "Sgd", weight_decay, classifier8)
# Out:
# start training for Sgd
# epoch  0
# train loss 1.914700450607763 train accuracy:  0.5430999994277954
# test loss 1.606513491543134 test accuracy 0.8601000308990479
# epoch  4 reached best accuracy  0.9549333453178406 %
# epoch  5 reached best accuracy  0.9617500305175781 %
# epoch  7 reached best accuracy  0.9642500281333923 %
# epoch  10 reached best accuracy  0.9685666561126709 %
# epoch  10
# train loss 1.5075271719941696 train accuracy:  0.9537999629974365
# test loss 1.4925581797361374 test accuracy 0.9685666561126709
# epoch  13 reached best accuracy  0.9713333249092102 %
# epoch  14 reached best accuracy  0.9722499847412109 %
# epoch  16 reached best accuracy  0.972599983215332 %
# epoch  17 reached best accuracy  0.9741166830062866 %
# epoch  20 reached best accuracy  0.9741666913032532 %
# epoch  20
# train loss 1.4934698743180346 train accuracy:  0.967799961566925
# test loss 1.4867907635589441 test accuracy 0.9741666913032532
# epoch  21 reached best accuracy  0.9761500358581543 %
# epoch  22 reached best accuracy  0.9764333367347717 %
# epoch  26 reached best accuracy  0.977316677570343 %
# epoch  28 reached best accuracy  0.9781500101089478 %
# epoch  30
# train loss 1.4918988181379276 train accuracy:  0.9691999554634094
# test loss 1.48391879499952 test accuracy 0.9770166873931885
# epoch  33 reached best accuracy  0.9788166880607605 %
# epoch  34 reached best accuracy  0.9795833230018616 %
# epoch  37 reached best accuracy  0.9797999858856201 %
# epoch  38 reached best accuracy  0.9802166819572449 %
# epoch  40 reached best accuracy  0.980733335018158 %
# epoch  40
# train loss 1.4821103518001568 train accuracy:  0.9786999821662903
# test loss 1.4804574687282244 test accuracy 0.980733335018158
# epoch  47 reached best accuracy  0.98089998960495 %
# epoch  48 reached best accuracy  0.9819499850273132 %
# epoch  50
# train loss 1.47668689889268 train accuracy:  0.9846999645233154
# test loss 1.4798819263637066 test accuracy 0.9813500046730042
# epoch  52 reached best accuracy  0.9833333492279053 %
# epoch  55 reached best accuracy  0.9835333228111267 %
# epoch  60
# train loss 1.4762900153668925 train accuracy:  0.9851999878883362
# test loss 1.4779784866372745 test accuracy 0.9830333590507507
# epoch  70
# train loss 1.4769834698960422 train accuracy:  0.9835000038146973
# test loss 1.479326754629612 test accuracy 0.9818000197410583
# epoch  72 reached best accuracy  0.9836000204086304 %
# epoch  73 reached best accuracy  0.9836500287055969 %
# epoch  74 reached best accuracy  0.9843167066574097 %
# epoch  80
# train loss 1.4738807183104201 train accuracy:  0.9870999455451965
# test loss 1.4779797045091787 test accuracy 0.9831166863441467
# epoch  82 reached best accuracy  0.9843666553497314 %
# epoch  86 reached best accuracy  0.98458331823349 %
# epoch  87 reached best accuracy  0.9846833348274231 %
# epoch  90
# train loss 1.47332528642953 train accuracy:  0.9879999756813049
# test loss 1.4770108814060687 test accuracy 0.984083354473114
# epoch  91 reached best accuracy  0.9849833250045776 %
# epoch  95 reached best accuracy  0.9850000143051147 %
# epoch  99 reached best accuracy  0.9853500127792358 %
# execution time ======= 8642.168380975723

# %%
classifier9 = Model8().to("cuda")
batch_size = 32
epoch = 120
learning_rate_value = 0.12
weight_decay = 0.9

# %%
loss_train_9, loss_test_9, acc_train_9, acc_test_9, best_9 = startTraining(batch_size,epoch,learning_rate_value, "Sgd", weight_decay, classifier8)

# %% [markdown]
# # Outputs

# %% [markdown]
# # 1. Plot the training and testing losses over epochs [2pt]

# %%
plt.figure(1,figsize=(10,10))

plt.plot(loss_train_8,label="train loss",c="red")
plt.plot(loss_test_8,label="test loss",c="blue")
plt.title("Loss")
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# # 2. Plot the training and testing accuracies over epochs [2pt]

# %%
plt.figure(1,figsize=(10,10))

plt.plot(acc_train_8,label="train accuracy",c="red")
plt.plot(acc_test_8,label="test accuracy",c="blue")
plt.title("Accuracy")
plt.legend(loc=4)
plt.plot()
# Out:
# []

# %% [markdown]
# # 3. Print the final training and testing losses at convergence [2pt]

# %%
print("training loss  %.5f" %loss_train_8[best_8])
print("testing loss   %.5f" %loss_test_8[best_8])
# Out:
# training loss  1.47291
# testing loss   1.47589

# %% [markdown]
# # 4. Print the final training and testing accuracies at convergence [20pt]

# %%
print("training accuracy %.5f "%acc_train_8[best_8])
print("testing accuracy  %.5f "%acc_test_8[best_8])
# Out:
# training accuracy 0.98820
# testing accuracy  0.98535

# %% [markdown]
# # 5. Print the testing accuracies within the last 10 epochs [5pt]

# %%
i = best_8 - 9
while i <= best_8:
    print("[epoch = %d] %.5f" %(i, acc_test_8[best_8]))
    i += 1
# Out:
# [epoch = 90] 0.98535
# [epoch = 91] 0.98535
# [epoch = 92] 0.98535
# [epoch = 93] 0.98535
# [epoch = 94] 0.98535
# [epoch = 95] 0.98535
# [epoch = 96] 0.98535
# [epoch = 97] 0.98535
# [epoch = 98] 0.98535
# [epoch = 99] 0.98535
